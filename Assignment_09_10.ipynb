# %%
import numpy as np
import matplotlib.pyplot as ply
import seaborn as sns
d=sns.load_dataset('diamonds')
d
# Out:
#        carat        cut color clarity  depth  table  price     x     y     z
# 0       0.23      Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1       0.21    Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2       0.23       Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3       0.29    Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4       0.31       Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# ...      ...        ...   ...     ...    ...    ...    ...   ...   ...   ...
# 53935   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75  5.76  3.50
# 53936   0.72       Good     D     SI1   63.1   55.0   2757  5.69  5.75  3.61
# 53937   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66  5.68  3.56
# 53938   0.86    Premium     H     SI2   61.0   58.0   2757  6.15  6.12  3.74
# 53939   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83  5.87  3.64
#
# [53940 rows x 10 columns]

# %%
sns.histplot(data=d,y='carat',x='price',hue='cut')
# Out:
# <Axes: xlabel='price', ylabel='carat'>

# %%
sns.jointplot(data=d,y='carat',x='price',hue='color')

# %%
sns.kdeplot(data=d,x='price',y='carat',hue='clarity')
# Out:
# <Axes: xlabel='price', ylabel='carat'>

# %%
sns.pairplot(data=d[['carat','price','clarity']],hue='clarity')

# %%
from seaborn.utils import load_dataset
t=load_dataset('tips')
t
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.histplot(data=t,x='total_bill',y='tip',hue='sex')
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
sns.jointplot(data=t,x='total_bill',y='tip',hue='time')

# %%
sns.kdeplot(data=t,x='total_bill',y='tip',hue='smoker')
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
sns.pairplot(data=t,hue='day')

# %%
sns.boxplot(data=t)
# Out:
# <Axes: >

# %%
p=sns.load_dataset('planets')
p
# Out:
#                method  number  orbital_period   mass  distance  year
# 0     Radial Velocity       1      269.300000   7.10     77.40  2006
# 1     Radial Velocity       1      874.774000   2.21     56.95  2008
# 2     Radial Velocity       1      763.000000   2.60     19.84  2011
# 3     Radial Velocity       1      326.030000  19.40    110.62  2007
# 4     Radial Velocity       1      516.220000  10.50    119.47  2009
# ...               ...     ...             ...    ...       ...   ...
# 1030          Transit       1        3.941507    NaN    172.00  2006
# 1031          Transit       1        2.615864    NaN    148.00  2007
# 1032          Transit       1        3.191524    NaN    174.00  2007
# 1033          Transit       1        4.125083    NaN    293.00  2008
# 1034          Transit       1        4.187757    NaN    260.00  2008
#
# [1035 rows x 6 columns]

# %%
sns.histplot(data=p,x='year',hue='method')
# Out:
# <Axes: xlabel='year', ylabel='Count'>

# %%
sns.jointplot(data=p)

# %%
sns.kdeplot(data=p,x='year',hue='method')
# Out:
# <ipython-input-70-6bb676975982>:1: UserWarning: Dataset has 0 variance; skipping density estimate. Pass `warn_singular=False` to disable this warning.
#   sns.kdeplot(data=p,x='year',hue='method')
# <Axes: xlabel='year', ylabel='Density'>

# %%
sns.pairplot(data=p,hue='method')
